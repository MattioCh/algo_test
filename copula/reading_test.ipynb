# %%
import pandas as pd

# %%
df = pd.read_pickle("test5.csv")

# %%
df
# Out:
#                               P1     P2  algo_volatility  \
# 2000-11-20 21:00:00+00:00    NaN    NaN              NaN
# 2000-11-21 21:00:00+00:00    NaN    NaN         0.000000
# 2000-11-22 21:00:00+00:00    NaN    NaN         0.000000
# 2000-11-24 18:00:00+00:00    NaN    NaN         0.000000
# 2000-11-27 21:00:00+00:00    NaN    NaN         0.000000
# 2000-11-28 21:00:00+00:00    NaN    NaN         0.000000
# 2000-11-29 21:00:00+00:00    NaN    NaN         0.000000
# 2000-11-30 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-01 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-04 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-05 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-06 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-07 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-08 21:00:00+00:00    NaN    NaN         0.000000
# 2000-12-11 21:00:00+00:00    NaN    NaN         0.000000
# ...
