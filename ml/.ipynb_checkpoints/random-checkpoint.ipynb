# %%
# Market prediction with machine learning 
# Simple one

# %%
import pandas as pd

# %%
raw = pd.read_csv('http://hilpisch.com/pyalgo_eikon_eod_data.csv')

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2609 entries, 0 to 2608
# Data columns (total 13 columns):
# Date      2609 non-null object
# AAPL.O    2516 non-null float64
# MSFT.O    2516 non-null float64
# INTC.O    2516 non-null float64
# AMZN.O    2516 non-null float64
# GS.N      2516 non-null float64
# SPY       2516 non-null float64
# .SPX      2516 non-null float64
# .VIX      2516 non-null float64
# EUR=      2609 non-null float64
# XAU=      2602 non-null float64
# GDX       2516 non-null float64
# GLD       2516 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 265.1+ KB

# %%
raw
# Out:
#             Date      AAPL.O   MSFT.O  INTC.O    AMZN.O    GS.N     SPY  \
# 0     2010-01-01         NaN      NaN     NaN       NaN     NaN     NaN
# 1     2010-01-04   30.572827   30.950  20.880   133.900  173.08  113.33
# 2     2010-01-05   30.625684   30.960  20.870   134.690  176.14  113.63
# 3     2010-01-06   30.138541   30.770  20.800   132.250  174.26  113.71
# 4     2010-01-07   30.082827   30.452  20.600   130.000  177.67  114.19
# 5     2010-01-08   30.282827   30.660  20.830   133.520  174.31  114.57
# 6     2010-01-11   30.015684   30.270  20.950   130.308  171.56  114.73
# 7     2010-01-12   29.674256   30.070  20.608   127.350  167.82  113.66
# 8     2010-01-13   30.092827   30.350  20.960   129.110  169.07  114.62
# 9     2010-01-14   29.918542   30.960  21.480   127.350  168.53  114.93
# 10    2010-01-15   29.418542   30.860  20.800   127.140  165.21  113.64
# 11    2010-01-18         NaN      NaN     NaN       NaN     NaN     NaN
# 12    2010-01-19   30.719969   31.100  21.050   127.610  166.86  115.06
# 13    2010-01-20   30.246398   30.585  21.080   125.780  167.79  113.89
# 14    2010-01-21   29.724542   30.010  20.840   126.620  160.87  111.70
# 15    2010-01-22   28.249972   28.960  19.910   121.430  154.12  109.21
# 16    2010-01-25   29.010685   29.320  20.320   120.310  154.98  109.77
# 17    2010-01-26   29.419971   29.500  20.000   119.480  150.88  109.31
# 18    2010-01-27   29.697685   29.670  20.240   122.750  151.50  109.83
# 19    2010-01-28   28.469972   29.160  19.920   126.030  153.29  108.57
# 20    2010-01-29   27.437544   28.180  19.400   125.410  148.72  107.39
# 21    2010-02-01   27.818544   28.410  19.610   118.870  153.13  109.06
# 22    2010-02-02   27.979972   28.460  19.910   118.120  156.94  110.38
# 23    2010-02-03   28.461400   28.630  19.680   119.100  157.23  109.83
# 24    2010-02-04   27.435687   27.840  19.020   115.940  150.68  106.44
# 25    2010-02-05   27.922829   28.020  19.470   117.390  154.16  106.66
# 26    2010-02-08   27.731401   27.720  19.350   116.830  151.10  105.89
# 27    2010-02-09   28.027115   28.010  19.650   118.030  152.49  107.22
# 28    2010-02-10   27.873686   27.990  19.690   117.360  153.63  107.01
# 29    2010-02-11   28.381400   28.120  20.060   120.090  154.05  108.13
# ...          ...         ...      ...     ...       ...     ...     ...
# 2579  2019-11-21  262.010000  149.480  58.220  1734.710  218.23  310.27
# 2580  2019-11-22  261.780000  149.590  57.610  1745.720  220.28  310.96
# 2581  2019-11-25  266.370000  151.230  58.810  1773.840  222.75  313.37
# 2582  2019-11-26  264.290000  152.030  58.900  1796.940  222.45  314.08
# 2583  2019-11-27  267.840000  152.320  58.510  1818.510  222.95  315.48
# 2584  2019-11-28         NaN      NaN     NaN       NaN     NaN     NaN
# 2585  2019-11-29  267.250000  151.380  58.050  1800.800  221.35  314.31
# 2586  2019-12-02  264.160000  149.550  57.660  1781.600  217.64  311.64
# 2587  2019-12-03  259.450000  149.310  56.070  1769.960  212.24  309.55
# 2588  2019-12-04  261.740000  149.850  56.020  1760.690  215.94  311.46
# 2589  2019-12-05  265.580000  149.930  56.080  1740.480  217.14  312.02
# 2590  2019-12-06  270.710000  151.750  56.810  1751.600  224.61  314.87
# 2591  2019-12-09  266.920000  151.360  56.530  1749.510  221.81  313.88
# 2592  2019-12-10  268.480000  151.130  56.590  1739.210  221.88  313.53
# 2593  2019-12-11  270.770000  151.700  57.070  1748.720  221.19  314.42
# 2594  2019-12-12  271.460000  153.240  57.550  1760.330  226.05  317.13
# 2595  2019-12-13  275.150000  154.530  57.790  1760.940  225.00  317.32
# 2596  2019-12-16  279.860000  155.530  57.700  1769.210  228.04  319.50
# 2597  2019-12-17  280.410000  154.690  57.300  1790.660  231.15  319.57
# 2598  2019-12-18  279.740000  154.370  57.170  1784.030  230.45  319.59
# 2599  2019-12-19  280.020000  155.710  57.960  1792.280  229.94  320.90
# 2600  2019-12-20  279.440000  157.410  58.950  1786.500  228.93  320.73
# 2601  2019-12-23  284.000000  157.410  59.230  1793.000  229.09  321.22
# 2602  2019-12-24  284.270000  157.380  59.410  1789.210  229.91  321.23
# 2603  2019-12-25         NaN      NaN     NaN       NaN     NaN     NaN
# 2604  2019-12-26  289.910000  158.670  59.820  1868.770  231.21  322.94
# 2605  2019-12-27  289.800000  158.960  60.080  1869.800  230.66  322.86
# 2606  2019-12-30  291.520000  157.590  59.620  1846.890  229.80  321.08
# 2607  2019-12-31  293.650000  157.700  59.850  1847.840  229.93  321.86
# 2608  2020-01-01         NaN      NaN     NaN       NaN     NaN     NaN
#
#          .SPX   .VIX    EUR=       XAU=    GDX      GLD
# 0         NaN    NaN  1.4323  1096.3500    NaN      NaN
# 1     1132.99  20.04  1.4411  1120.0000  47.71  109.800
# 2     1136.52  19.35  1.4368  1118.6500  48.17  109.700
# 3     1137.14  19.16  1.4412  1138.5000  49.34  111.510
# 4     1141.69  19.06  1.4318  1131.9000  49.10  110.820
# 5     1144.98  18.13  1.4412  1136.1000  49.84  111.370
# 6     1146.98  17.55  1.4513  1152.6000  50.17  112.850
# 7     1136.22  18.25  1.4494  1127.3000  48.35  110.490
# 8     1145.68  17.85  1.4510  1138.4000  48.86  111.540
# 9     1148.46  17.63  1.4502  1142.8500  48.60  112.030
# 10    1136.03  17.91  1.4382  1129.9000  47.42  110.860
# 11        NaN    NaN  1.4385  1132.5000    NaN      NaN
# 12    1150.23  17.58  1.4298  1137.7000  47.69  111.520
# 13    1138.04  18.68  1.4101  1111.3000  45.73  108.940
# 14    1116.48  22.27  1.4090  1094.7500  43.75  107.370
# 15    1091.76  27.31  1.4137  1092.6000  43.79  107.170
# 16    1096.78  25.41  1.4150  1097.8500  43.19  107.480
# 17    1092.17  24.55  1.4073  1097.6500  43.13  107.560
# 18    1097.50  23.14  1.4017  1086.3500  42.77  106.528
# 19    1084.53  23.73  1.3962  1085.9000  42.17  106.480
# 20    1073.87  24.62  1.3862  1081.0500  40.72  105.960
# 21    1089.19  22.59  1.3927  1106.9500  42.94  108.350
# 22    1103.32  21.48  1.3961  1114.8000  43.00  109.130
# 23    1097.28  21.60  1.3898  1109.2500  42.57  108.700
# 24    1063.11  26.08  1.3734  1063.0500  40.24  104.370
# 25    1066.19  26.11  1.3662  1064.9500  42.41  104.680
# 26    1056.74  26.51  1.3652  1063.3500  40.78  104.040
# 27    1070.52  26.00  1.3789  1076.9000  42.57  105.410
# 28    1068.13  25.40  1.3726  1072.4500  42.35  105.120
# 29    1078.47  23.96  1.3681  1094.9500  43.99  107.130
# ...       ...    ...     ...        ...    ...      ...
# 2579  3103.54  13.13  1.1057  1464.1500  26.82  138.000
# 2580  3110.29  12.34  1.1022  1462.0400  26.76  137.740
# 2581  3133.64  11.87  1.1013  1454.8738  26.20  137.080
# 2582  3140.52  11.54  1.1018  1461.2000  26.78  137.740
# 2583  3153.63  11.75  1.0998  1454.2500  26.66  137.010
# 2584      NaN    NaN  1.1007  1458.0917    NaN      NaN
# 2585  3140.98  12.62  1.1015  1463.9000  27.08  137.860
# 2586  3113.87  14.91  1.1077  1462.3400  27.17  137.790
# 2587  3093.20  15.96  1.1081  1477.2410  27.77  139.110
# 2588  3112.76  14.80  1.1076  1474.1000  27.48  138.920
# 2589  3117.43  14.52  1.1102  1475.6029  27.62  139.000
# 2590  3145.91  13.62  1.1057  1459.5071  26.97  137.620
# 2591  3135.96  15.86  1.1062  1461.8900  26.92  137.580
# 2592  3132.52  15.68  1.1092  1463.9600  27.13  137.970
# 2593  3141.63  14.99  1.1128  1474.7500  27.71  138.920
# 2594  3168.57  13.94  1.1128  1469.3300  27.66  138.430
# 2595  3168.80  12.63  1.1119  1475.5586  27.72  139.050
# 2596  3191.45  12.14  1.1142  1476.0013  27.39  139.040
# 2597  3192.52  12.29  1.1149  1476.2000  27.16  139.010
# 2598  3191.14  12.58  1.1111  1475.1862  27.45  139.020
# 2599  3205.37  12.50  1.1120  1479.0472  27.48  139.380
# 2600  3221.22  12.51  1.1078  1477.9497  27.13  139.520
# 2601  3224.01  12.61  1.1086  1485.2700  27.77  139.950
# 2602  3223.38  12.67  1.1087  1498.8100  28.66  141.270
# 2603      NaN    NaN  1.1090  1498.6000    NaN      NaN
# 2604  3239.91  12.65  1.1096  1511.2979  29.08  142.380
# 2605  3240.02  13.43  1.1175  1510.4167  28.87  142.330
# 2606  3221.29  14.82  1.1197  1515.1230  29.49  142.630
# 2607  3230.78  13.78  1.1210  1517.0100  29.28  142.900
# 2608      NaN    NaN  1.1210  1516.8900    NaN      NaN
#
# [2609 rows x 13 columns]

# %%
symbol = 'EUR='
data = pd.DataFrame(raw[symbol])

# %%
data.rename(columns={symbol: 'price'}, inplace=True)

# %%
lags = 5 # looking back for 5 data

# %%
cols = []
for lag in range(1, lags + 1):
    col = f'lag_{lag}'
    data[col] = data['price'].shift(lag)
    cols.append(col)
data.dropna(inplace=True)

# %%
import numpy as np

# %%
reg = np.linalg.lstsq(data[cols], data['price'], rcond=None)[0]

# %%
reg
# Out:
# array([ 9.83507422e-01,  2.21100214e-02, -4.66748285e-02,  4.18699241e-02,
#        -9.32399599e-04])

# %%
data['prediction'] = np.dot(data[cols], reg)

# %%
data[['price', 'prediction']].plot(figsize=(10, 6));

# %%
data.index = raw['Date'].loc[5:]

# %%
data[['price', 'prediction']].loc['2019-10-1':].plot(figsize=(10, 6))
# Out:
# C:\Users\Magdalene\anaconda3\envs\env_zipline\lib\site-packages\pandas\plotting\_core.py:394: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:xlabel='Date'>

# %%
# Predicting future returns

# %%
data['return'] = np.log(data['price'] / data['price'].shift(1))

# %%
data.dropna(inplace=True)

# %%
cols = []
for lag in range(1, lags + 1):
    col = f'lag_{lag}'
    data[col] = data['return'].shift(lag)
    cols.append(col)
data.dropna(inplace=True)

# %%
reg = np.linalg.lstsq(data[cols], data['return'], rcond=None)[0]
reg
# Out:
# array([-0.01659146,  0.00791021, -0.04093551,  0.00313403,  0.01523923])

# %%
data['prediction2'] = np.dot(data[cols], reg)
data[['return', 'prediction2']].iloc[lags:].plot(figsize=(10, 6));
# Out:
# C:\Users\Magdalene\anaconda3\envs\env_zipline\lib\site-packages\pandas\plotting\_core.py:394: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
# Conclude that linear regression cannot predict magnitude of log returns 
# improvement 1: instead, prediction for DIRECTION of forecasted return 
# if sign of prediction is correct, product of return and prediction2 will be positive
# else, negative

# %%
hits = np.sign(data['return'] * data['prediction2']).value_counts()

# %%
hits
# Out:
#  1.0    1308
# -1.0    1273
#  0.0      17
# dtype: int64

# %%
hits.values[0] / sum(hits)
# hit ratio - correct predicted directions 
# slightly more accurate than random guessing?
# Out:
# 0.5034642032332564

# %%
# improvement 2: use the signs for the log returns as dependent variables instead

# %%
reg = np.linalg.lstsq(data[cols], np.sign(data['return']), rcond=None)[0]

# %%
reg
# Out:
# array([-5.37247476, -4.2656618 , -7.00656452, -2.78442156,  0.92897295])

# %%
data['prediction3'] = np.sign(np.dot(data[cols], reg))

# %%
data['prediction3'].value_counts()
# Out:
#  1.0    1322
# -1.0    1276
# Name: prediction3, dtype: int64

# %%
hits = np.sign(data['return'] * data['prediction3']).value_counts()

# %%
hits
# Out:
#  1.0    1324
# -1.0    1257
#  0.0      17
# dtype: int64

# %%
hits.values[0] / sum(hits)
# Out:
# 0.5096227867590454

# %%
# trading logic: when prediction is positive - upward trend - long/buy
# prediction negative - downward trend - short/sell

# %%
data.head()
# Out:
#              price     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2010-01-18  1.4385 -0.008309 -0.000551  0.001103 -0.001310  0.006984
# 2010-01-19  1.4298  0.000209 -0.008309 -0.000551  0.001103 -0.001310
# 2010-01-20  1.4101 -0.006066  0.000209 -0.008309 -0.000551  0.001103
# 2010-01-21  1.4090 -0.013874 -0.006066  0.000209 -0.008309 -0.000551
# 2010-01-22  1.4137 -0.000780 -0.013874 -0.006066  0.000209 -0.008309
#
#             prediction    return  prediction2  prediction3
# Date
# 2010-01-18    1.438152  0.000209     0.000191          1.0
# 2010-01-19    1.438288 -0.006066    -0.000063          1.0
# 2010-01-20    1.430263 -0.013874     0.000458          1.0
# 2010-01-21    1.410180 -0.000780     0.000139          1.0
# 2010-01-22    1.409093  0.003330     0.000026          1.0

# %%
data['strategy'] = data['prediction3'] * data['return']
data[['return', 'strategy']].sum().apply(np.exp)
# Out:
# return      0.779447
# strategy    1.319244
# dtype: float64

# %%
data[['return', 'strategy']].dropna().cumsum().apply(np.exp).plot(figsize=(10, 6));
# Out:
# C:\Users\Magdalene\anaconda3\envs\env_zipline\lib\site-packages\pandas\plotting\_core.py:394: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
'''
basic idea - use the signs of return within a previous period (lag)
to predict the trend of return - if positive (upward trend), then long
else, short 
'''
# Out:
# '\nbasic idea - use the signs of return within a previous period (lag)\nto predict the trend of return - if positive (upward trend), then long\nelse, short \n'

# %%
# scikit-learn - model selection - model fitting - prediction
from sklearn import linear_model

# %%
# logistic regression to classify market direction (+/-)
symbol = 'GLD'
data = pd.DataFrame(raw[symbol])

# %%
data.rename(columns={symbol: 'price'}, inplace=True)
data['return'] = np.log(data['price'] / data['price'].shift(1))
data.dropna(inplace=True)

# %%
lags = 3
cols = []
for lag in range(1, lags+1):
    col = 'lag_{}'.format(lag)
    data[col] = data['return'].shift(lag)
    cols.append(col)
data.dropna(inplace=True)

# %%
from sklearn.metrics import accuracy_score
lm = linear_model.LogisticRegression(C=1e7, solver='lbfgs', multi_class='auto', max_iter=1000)
lm.fit(data[cols], np.sign(data['return']))
# Out:
# LogisticRegression(C=10000000.0, max_iter=1000)

# %%
data['prediction'] = lm.predict(data[cols])
data['prediction'].value_counts()
# Out:
#  1.0    1820
# -1.0     602
# Name: prediction, dtype: int64

# %%
hits = np.sign(data['return'].iloc[lags:] * data['prediction'].iloc[lags:]).value_counts()

# %%
hits
# Out:
#  1.0    1265
# -1.0    1143
#  0.0      11
# dtype: int64

# %%
accuracy_score(data['prediction'], np.sign(data['return']))
# Out:
# 0.523534269199009

# %%
data['strategy'] = data['prediction'] * data['return']
data[['return', 'strategy']].sum().apply(np.exp)
# Out:
# return      1.126476
# strategy    2.117445
# dtype: float64

# %%
data[['return', 'strategy']].cumsum().apply(np.exp).plot(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
# notes - change the parameters in the class - use different formulas 
# use different lags  
# NEXT: using deep neural networks to predict market direction 
# NEXT: install Tensorflow and Keras **think about dependencies
