# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe
data = pdr.get_data_yahoo("AAPL", period="60d", interval="2m")
import matplotlib.pyplot as plt
plt.plot(data.Close)

data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2020-11-06 09:30:00-05:00         NaN         NaN         NaN         NaN
# 2020-11-18 09:30:00-05:00  118.610001  119.019997  118.309998  118.684998
# 2020-11-18 09:32:00-05:00  118.690002  118.730003  118.239998  118.377701
# 2020-11-18 09:34:00-05:00  118.379997  118.809998  118.339996  118.735001
# 2020-11-18 09:36:00-05:00  118.730003  118.930000  118.650002  118.889999
#
#                             Adj Close     Volume
# Datetime
# 2020-11-06 09:30:00-05:00         NaN        NaN
# 2020-11-18 09:30:00-05:00  118.684998  4374489.0
# 2020-11-18 09:32:00-05:00  118.377701  1152326.0
# 2020-11-18 09:34:00-05:00  118.735001  1146747.0
# 2020-11-18 09:36:00-05:00  118.889999   851680.0

# %%
def DOHL_to_dohl_mapper(dataframe):
        map_column = {"Date":"date","High":"high","Open":"open","Low":"low","Close":"close","Volume":"volume","Adj Close":"adj close"}
        df_new = dataframe.rename(columns=map_column)
        df_new.index.name="date"
        return df_new

# %%
df = DOHL_to_dohl_mapper(data)
df.to_csv("20200106/minute/AAPL.csv")

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-10-09  115.279999  117.000000  114.919998  116.970001  116.768547
# 2020-10-12  120.059998  125.180000  119.279999  124.400002  124.185753
# 2020-10-13  125.269997  125.389999  119.650002  121.099998  120.891434
# 2020-10-14  121.000000  123.029999  119.620003  121.190002  120.981277
# 2020-10-15  118.720001  121.199997  118.150002  120.709999  120.502106
# 2020-10-16  121.279999  121.550003  118.809998  119.019997  118.815010
# 2020-10-19  119.959999  120.419998  115.660004  115.980003  115.780251
# 2020-10-20  116.199997  118.980003  115.629997  117.510002  117.307617
# 2020-10-21  116.669998  118.709999  116.449997  116.870003  116.668724
# 2020-10-22  117.449997  118.040001  114.589996  115.750000  115.550644
# 2020-10-23  116.389999  116.550003  114.279999  115.040001  114.841873
# ...
