# %%
import pandas as pd

# %%
df = pd.read_pickle("test.csv")

# %%
df.head()
# Out:
#                            algo_volatility  algorithm_period_return alpha  \
# 2006-01-03 21:00:00+00:00              NaN                      0.0  None
# 2006-01-04 21:00:00+00:00              0.0                      0.0  None
# 2006-01-05 21:00:00+00:00              0.0                      0.0  None
# 2006-01-06 21:00:00+00:00              0.0                      0.0  None
# 2006-01-09 21:00:00+00:00              0.0                      0.0  None
#
#                            benchmark_period_return  benchmark_volatility  \
# 2006-01-03 21:00:00+00:00                      0.0                   NaN
# 2006-01-04 21:00:00+00:00                      0.0                   0.0
# 2006-01-05 21:00:00+00:00                      0.0                   0.0
# 2006-01-06 21:00:00+00:00                      0.0                   0.0
# 2006-01-09 21:00:00+00:00                      0.0                   0.0
#
#                            beta  capital_used  ending_cash  ending_exposure  \
# ...

# %%
df.tail()
# Out:
#                            algo_volatility  algorithm_period_return alpha  \
# 2019-12-24 18:00:00+00:00         0.177320                 1.476972  None
# 2019-12-26 21:00:00+00:00         0.177299                 1.488972  None
# 2019-12-27 21:00:00+00:00         0.177274                 1.491972  None
# 2019-12-30 21:00:00+00:00         0.177249                 1.488972  None
# 2019-12-31 21:00:00+00:00         0.177228                 1.478972  None
#
#                            benchmark_period_return  benchmark_volatility  \
# 2019-12-24 18:00:00+00:00                      0.0                   0.0
# 2019-12-26 21:00:00+00:00                      0.0                   0.0
# 2019-12-27 21:00:00+00:00                      0.0                   0.0
# 2019-12-30 21:00:00+00:00                      0.0                   0.0
# 2019-12-31 21:00:00+00:00                      0.0                   0.0
#
#                            beta  capital_used  ending_cash  ending_exposure  \
# ...
